# %% [markdown]
# <a href="https://colab.research.google.com/github/Raisul1971/2/blob/master/LFDsheet8-exercise20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Load the Iris dataset
iris = datasets.load_iris()
X, y = iris.data, iris.target

# Convert to binary classification (classes 0 and 1)
X = X[y != 2]
y = y[y != 2]

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

kernels = ['linear', 'poly', 'rbf']

for kernel in kernels:
    clf = SVC(kernel=kernel)
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    print(f"Kernel: {kernel}, Accuracy: {acc:.2f}, Support Vectors: {len(clf.support_)}")
# Out:
# Kernel: linear, Accuracy: 1.00, Support Vectors: 3
# Kernel: poly, Accuracy: 1.00, Support Vectors: 3
# Kernel: rbf, Accuracy: 1.00, Support Vectors: 8
